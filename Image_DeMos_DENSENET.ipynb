# %%
import os
import matplotlib.pyplot as plt
import scipy.misc
import sklearn.feature_extraction
import numpy as np
import scipy.ndimage
from skimage import measure, io
from skimage import transform
import train_UNET 
import skimage
import json
import datetime
import pickle


save_results = r'C:\Users\buggyr\Mosaic_Experiments\models'
load_training = r'C:\Users\buggyr\Mosaic_Experiments\data\external\Training Images 3'

# %%
from keras.models import Model
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import AveragePooling2D
from keras.layers.pooling import GlobalAveragePooling2D
from keras.layers import Input, Concatenate
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adadelta, Nadam, RMSprop
import keras
import keras.backend as K

# %%
def conv_factory(x, nb_filter, dropout_rate=None, weight_decay=1E-4):
    """Apply BatchNorm, Relu 3x3Conv2D, optional dropout
    :param x: Input keras network
    :param nb_filter: int -- number of filters
    :param dropout_rate: int -- dropout rate
    :param weight_decay: int -- weight decay factor
    :returns: keras network with b_norm, relu and Conv2D added
    :rtype: keras network
    """

#     x = BatchNormalization(axis=1,
#                            gamma_regularizer=l2(weight_decay),
#                            beta_regularizer=l2(weight_decay))(x)
    x = Activation('relu')(x)
    x = Conv2D(nb_filter, (3, 3),
               kernel_initializer="he_uniform",
               padding="same",
               use_bias=False,
               kernel_regularizer=l2(weight_decay))(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x


def transition(x, nb_filter, dropout_rate=None, weight_decay=1E-4):
    """Apply BatchNorm, Relu 1x1Conv2D, optional dropout and Maxpooling2D
    :param x: keras model
    :param nb_filter: int -- number of filters
    :param dropout_rate: int -- dropout rate
    :param weight_decay: int -- weight decay factor
    :returns: model
    :rtype: keras model, after applying batch_norm, relu-conv, dropout, maxpool
    """

#     x = BatchNormalization(axis=1,
#                            gamma_regularizer=l2(weight_decay),
#                            beta_regularizer=l2(weight_decay))(x)
    x = Activation('relu')(x)
    x = Conv2D(nb_filter, (1, 1),
               kernel_initializer="he_uniform",
               padding="same",
               use_bias=False,
               kernel_regularizer=l2(weight_decay))(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)
    

    return x


def denseblock(x, nb_layers, nb_filter, growth_rate,
               dropout_rate=None, weight_decay=1E-4):
    """Build a denseblock where the output of each
       conv_factory is fed to subsequent ones
    :param x: keras model
    :param nb_layers: int -- the number of layers of conv_
                      factory to append to the model.
    :param nb_filter: int -- number of filters
    :param dropout_rate: int -- dropout rate
    :param weight_decay: int -- weight decay factor
    :returns: keras model with nb_layers of conv_factory appended
    :rtype: keras model
    """

    list_feat = [x]

    if K.image_dim_ordering() == "th":
        concat_axis = 1
    elif K.image_dim_ordering() == "tf":
        concat_axis = -1

    for i in range(nb_layers):
        x = conv_factory(x, growth_rate, dropout_rate, weight_decay)
        list_feat.append(x)
        x = Concatenate(axis=concat_axis)(list_feat)
        nb_filter += growth_rate

    return x, nb_filter


def denseblock_altern(x, nb_layers, nb_filter, growth_rate,
                      dropout_rate=None, weight_decay=1E-4):
    """Build a denseblock where the output of each conv_factory
       is fed to subsequent ones. (Alternative of a above)
    :param x: keras model
    :param nb_layers: int -- the number of layers of conv_
                      factory to append to the model.
    :param nb_filter: int -- number of filters
    :param dropout_rate: int -- dropout rate
    :param weight_decay: int -- weight decay factor
    :returns: keras model with nb_layers of conv_factory appended
    :rtype: keras model
    * The main difference between this implementation and the implementation
    above is that the one above
    """

    if K.image_dim_ordering() == "th":
        concat_axis = 1
    elif K.image_dim_ordering() == "tf":
        concat_axis = -1

    for i in range(nb_layers):
        merge_tensor = conv_factory(x, growth_rate, dropout_rate, weight_decay)
        x = Concatenate(axis=concat_axis)([merge_tensor, x])
        nb_filter += growth_rate

    return x, nb_filter


def DenseNet(img_dim, depth, nb_dense_block, growth_rate,
             nb_filter, dropout_rate=None, weight_decay=1E-4):
    """ Build the DenseNet model
    :param nb_classes: int -- number of classes
    :param img_dim: tuple -- (channels, rows, columns)
    :param depth: int -- how many layers
    :param nb_dense_block: int -- number of dense blocks to add to end
    :param growth_rate: int -- number of filters to add
    :param nb_filter: int -- number of filters
    :param dropout_rate: float -- dropout rate
    :param weight_decay: float -- weight decay
    :returns: keras model with nb_layers of conv_factory appended
    :rtype: keras model
    """

    model_input = Input(shape=img_dim)

    assert (depth - 4) % 3 == 0, "Depth must be 3 N + 4"

    # layers in each dense block
    nb_layers = int((depth - 4) / 3)

    # Initial convolution
    x = Conv2D(nb_filter, (3, 3),
               kernel_initializer="he_uniform",
               padding="same",
               name="initial_conv2D",
               use_bias=False,
               kernel_regularizer=l2(weight_decay))(model_input)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        x, nb_filter = denseblock(x, nb_layers, nb_filter, growth_rate,
                                  dropout_rate=dropout_rate,
                                  weight_decay=weight_decay)
        # add transition
        x = transition(x, nb_filter, dropout_rate=dropout_rate,
                       weight_decay=weight_decay)

    # The last denseblock is reurned to 3 channels
    x = Conv2D(3, (3, 3),
               kernel_initializer="he_uniform",
               padding="same",
               name="final_conv2D",
               use_bias=False,
               kernel_regularizer=l2(weight_decay))(x)

    densenet = Model(inputs=[model_input], outputs=[x], name="DenseNet")

    return densenet
model = DenseNet((None,None,4), 10, 50, 1,
             3, None, 1E-4)

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_9 (InputLayer)             (None, None, None, 4) 0
# ____________________________________________________________________________________________________
# initial_conv2D (Conv2D)          (None, None, None, 3) 108         input_9[0][0]
# ____________________________________________________________________________________________________
# activation_883 (Activation)      (None, None, None, 3) 0           initial_conv2D[0][0]
# ____________________________________________________________________________________________________
# conv2d_883 (Conv2D)              (None, None, None, 1) 27          activation_883[0][0]
# ____________________________________________________________________________________________________
# concatenate_589 (Concatenate)    (None, None, None, 4) 0           initial_conv2D[0][0]
#                                                                    conv2d_883[0][0]
# ____________________________________________________________________________________________________
# activation_884 (Activation)      (None, None, None, 4) 0           concatenate_589[0][0]
# ____________________________________________________________________________________________________
# conv2d_884 (Conv2D)              (None, None, None, 1) 36          activation_884[0][0]
# ____________________________________________________________________________________________________
# concatenate_590 (Concatenate)    (None, None, None, 5) 0           initial_conv2D[0][0]
#                                                                    conv2d_883[0][0]
#                                                                    conv2d_884[0][0]
# ____________________________________________________________________________________________________
# activation_885 (Activation)      (None, None, None, 5) 0           concatenate_590[0][0]
# ____________________________________________________________________________________________________
# conv2d_885 (Conv2D)              (None, None, None, 5) 25          activation_885[0][0]
# ____________________________________________________________________________________________________
# activation_886 (Activation)      (None, None, None, 5) 0           conv2d_885[0][0]
# ____________________________________________________________________________________________________
# conv2d_886 (Conv2D)              (None, None, None, 1) 45          activation_886[0][0]
# ____________________________________________________________________________________________________
# concatenate_591 (Concatenate)    (None, None, None, 6) 0           conv2d_885[0][0]
#                                                                    conv2d_886[0][0]
# ____________________________________________________________________________________________________
# activation_887 (Activation)      (None, None, None, 6) 0           concatenate_591[0][0]
# ____________________________________________________________________________________________________
# conv2d_887 (Conv2D)              (None, None, None, 1) 54          activation_887[0][0]
# ____________________________________________________________________________________________________
# concatenate_592 (Concatenate)    (None, None, None, 7) 0           conv2d_885[0][0]
#                                                                    conv2d_886[0][0]
#                                                                    conv2d_887[0][0]
# ____________________________________________________________________________________________________
# activation_888 (Activation)      (None, None, None, 7) 0           concatenate_592[0][0]
# ____________________________________________________________________________________________________
# conv2d_888 (Conv2D)              (None, None, None, 7) 49          activation_888[0][0]
# ____________________________________________________________________________________________________
# activation_889 (Activation)      (None, None, None, 7) 0           conv2d_888[0][0]
# ____________________________________________________________________________________________________
# conv2d_889 (Conv2D)              (None, None, None, 1) 63          activation_889[0][0]
# ____________________________________________________________________________________________________
# concatenate_593 (Concatenate)    (None, None, None, 8) 0           conv2d_888[0][0]
#                                                                    conv2d_889[0][0]
# ____________________________________________________________________________________________________
# activation_890 (Activation)      (None, None, None, 8) 0           concatenate_593[0][0]
# ____________________________________________________________________________________________________
# conv2d_890 (Conv2D)              (None, None, None, 1) 72          activation_890[0][0]
# ____________________________________________________________________________________________________
# concatenate_594 (Concatenate)    (None, None, None, 9) 0           conv2d_888[0][0]
#                                                                    conv2d_889[0][0]
#                                                                    conv2d_890[0][0]
# ____________________________________________________________________________________________________
# activation_891 (Activation)      (None, None, None, 9) 0           concatenate_594[0][0]
# ____________________________________________________________________________________________________
# conv2d_891 (Conv2D)              (None, None, None, 9) 81          activation_891[0][0]
# ____________________________________________________________________________________________________
# activation_892 (Activation)      (None, None, None, 9) 0           conv2d_891[0][0]
# ____________________________________________________________________________________________________
# conv2d_892 (Conv2D)              (None, None, None, 1) 81          activation_892[0][0]
# ____________________________________________________________________________________________________
# concatenate_595 (Concatenate)    (None, None, None, 10 0           conv2d_891[0][0]
#                                                                    conv2d_892[0][0]
# ____________________________________________________________________________________________________
# activation_893 (Activation)      (None, None, None, 10 0           concatenate_595[0][0]
# ____________________________________________________________________________________________________
# conv2d_893 (Conv2D)              (None, None, None, 1) 90          activation_893[0][0]
# ____________________________________________________________________________________________________
# concatenate_596 (Concatenate)    (None, None, None, 11 0           conv2d_891[0][0]
#                                                                    conv2d_892[0][0]
#                                                                    conv2d_893[0][0]
# ____________________________________________________________________________________________________
# activation_894 (Activation)      (None, None, None, 11 0           concatenate_596[0][0]
# ____________________________________________________________________________________________________
# conv2d_894 (Conv2D)              (None, None, None, 11 121         activation_894[0][0]
# ____________________________________________________________________________________________________
# activation_895 (Activation)      (None, None, None, 11 0           conv2d_894[0][0]
# ____________________________________________________________________________________________________
# conv2d_895 (Conv2D)              (None, None, None, 1) 99          activation_895[0][0]
# ____________________________________________________________________________________________________
# concatenate_597 (Concatenate)    (None, None, None, 12 0           conv2d_894[0][0]
#                                                                    conv2d_895[0][0]
# ____________________________________________________________________________________________________
# activation_896 (Activation)      (None, None, None, 12 0           concatenate_597[0][0]
# ____________________________________________________________________________________________________
# conv2d_896 (Conv2D)              (None, None, None, 1) 108         activation_896[0][0]
# ____________________________________________________________________________________________________
# concatenate_598 (Concatenate)    (None, None, None, 13 0           conv2d_894[0][0]
#                                                                    conv2d_895[0][0]
#                                                                    conv2d_896[0][0]
# ____________________________________________________________________________________________________
# activation_897 (Activation)      (None, None, None, 13 0           concatenate_598[0][0]
# ____________________________________________________________________________________________________
# conv2d_897 (Conv2D)              (None, None, None, 13 169         activation_897[0][0]
# ____________________________________________________________________________________________________
# activation_898 (Activation)      (None, None, None, 13 0           conv2d_897[0][0]
# ____________________________________________________________________________________________________
# conv2d_898 (Conv2D)              (None, None, None, 1) 117         activation_898[0][0]
# ____________________________________________________________________________________________________
# concatenate_599 (Concatenate)    (None, None, None, 14 0           conv2d_897[0][0]
#                                                                    conv2d_898[0][0]
# ____________________________________________________________________________________________________
# activation_899 (Activation)      (None, None, None, 14 0           concatenate_599[0][0]
# ____________________________________________________________________________________________________
# conv2d_899 (Conv2D)              (None, None, None, 1) 126         activation_899[0][0]
# ____________________________________________________________________________________________________
# concatenate_600 (Concatenate)    (None, None, None, 15 0           conv2d_897[0][0]
#                                                                    conv2d_898[0][0]
#                                                                    conv2d_899[0][0]
# ____________________________________________________________________________________________________
# activation_900 (Activation)      (None, None, None, 15 0           concatenate_600[0][0]
# ____________________________________________________________________________________________________
# conv2d_900 (Conv2D)              (None, None, None, 15 225         activation_900[0][0]
# ____________________________________________________________________________________________________
# activation_901 (Activation)      (None, None, None, 15 0           conv2d_900[0][0]
# ____________________________________________________________________________________________________
# conv2d_901 (Conv2D)              (None, None, None, 1) 135         activation_901[0][0]
# ____________________________________________________________________________________________________
# concatenate_601 (Concatenate)    (None, None, None, 16 0           conv2d_900[0][0]
#                                                                    conv2d_901[0][0]
# ____________________________________________________________________________________________________
# activation_902 (Activation)      (None, None, None, 16 0           concatenate_601[0][0]
# ____________________________________________________________________________________________________
# conv2d_902 (Conv2D)              (None, None, None, 1) 144         activation_902[0][0]
# ____________________________________________________________________________________________________
# concatenate_602 (Concatenate)    (None, None, None, 17 0           conv2d_900[0][0]
#                                                                    conv2d_901[0][0]
#                                                                    conv2d_902[0][0]
# ____________________________________________________________________________________________________
# activation_903 (Activation)      (None, None, None, 17 0           concatenate_602[0][0]
# ____________________________________________________________________________________________________
# conv2d_903 (Conv2D)              (None, None, None, 17 289         activation_903[0][0]
# ____________________________________________________________________________________________________
# activation_904 (Activation)      (None, None, None, 17 0           conv2d_903[0][0]
# ____________________________________________________________________________________________________
# conv2d_904 (Conv2D)              (None, None, None, 1) 153         activation_904[0][0]
# ____________________________________________________________________________________________________
# concatenate_603 (Concatenate)    (None, None, None, 18 0           conv2d_903[0][0]
#                                                                    conv2d_904[0][0]
# ____________________________________________________________________________________________________
# activation_905 (Activation)      (None, None, None, 18 0           concatenate_603[0][0]
# ____________________________________________________________________________________________________
# conv2d_905 (Conv2D)              (None, None, None, 1) 162         activation_905[0][0]
# ____________________________________________________________________________________________________
# concatenate_604 (Concatenate)    (None, None, None, 19 0           conv2d_903[0][0]
#                                                                    conv2d_904[0][0]
#                                                                    conv2d_905[0][0]
# ____________________________________________________________________________________________________
# activation_906 (Activation)      (None, None, None, 19 0           concatenate_604[0][0]
# ____________________________________________________________________________________________________
# conv2d_906 (Conv2D)              (None, None, None, 19 361         activation_906[0][0]
# ____________________________________________________________________________________________________
# activation_907 (Activation)      (None, None, None, 19 0           conv2d_906[0][0]
# ____________________________________________________________________________________________________
# conv2d_907 (Conv2D)              (None, None, None, 1) 171         activation_907[0][0]
# ____________________________________________________________________________________________________
# concatenate_605 (Concatenate)    (None, None, None, 20 0           conv2d_906[0][0]
#                                                                    conv2d_907[0][0]
# ____________________________________________________________________________________________________
# activation_908 (Activation)      (None, None, None, 20 0           concatenate_605[0][0]
# ____________________________________________________________________________________________________
# conv2d_908 (Conv2D)              (None, None, None, 1) 180         activation_908[0][0]
# ____________________________________________________________________________________________________
# concatenate_606 (Concatenate)    (None, None, None, 21 0           conv2d_906[0][0]
#                                                                    conv2d_907[0][0]
#                                                                    conv2d_908[0][0]
# ____________________________________________________________________________________________________
# activation_909 (Activation)      (None, None, None, 21 0           concatenate_606[0][0]
# ____________________________________________________________________________________________________
# conv2d_909 (Conv2D)              (None, None, None, 21 441         activation_909[0][0]
# ____________________________________________________________________________________________________
# activation_910 (Activation)      (None, None, None, 21 0           conv2d_909[0][0]
# ____________________________________________________________________________________________________
# conv2d_910 (Conv2D)              (None, None, None, 1) 189         activation_910[0][0]
# ____________________________________________________________________________________________________
# concatenate_607 (Concatenate)    (None, None, None, 22 0           conv2d_909[0][0]
#                                                                    conv2d_910[0][0]
# ____________________________________________________________________________________________________
# activation_911 (Activation)      (None, None, None, 22 0           concatenate_607[0][0]
# ____________________________________________________________________________________________________
# conv2d_911 (Conv2D)              (None, None, None, 1) 198         activation_911[0][0]
# ____________________________________________________________________________________________________
# concatenate_608 (Concatenate)    (None, None, None, 23 0           conv2d_909[0][0]
#                                                                    conv2d_910[0][0]
#                                                                    conv2d_911[0][0]
# ____________________________________________________________________________________________________
# activation_912 (Activation)      (None, None, None, 23 0           concatenate_608[0][0]
# ____________________________________________________________________________________________________
# conv2d_912 (Conv2D)              (None, None, None, 23 529         activation_912[0][0]
# ____________________________________________________________________________________________________
# activation_913 (Activation)      (None, None, None, 23 0           conv2d_912[0][0]
# ____________________________________________________________________________________________________
# conv2d_913 (Conv2D)              (None, None, None, 1) 207         activation_913[0][0]
# ____________________________________________________________________________________________________
# concatenate_609 (Concatenate)    (None, None, None, 24 0           conv2d_912[0][0]
#                                                                    conv2d_913[0][0]
# ____________________________________________________________________________________________________
# activation_914 (Activation)      (None, None, None, 24 0           concatenate_609[0][0]
# ____________________________________________________________________________________________________
# conv2d_914 (Conv2D)              (None, None, None, 1) 216         activation_914[0][0]
# ____________________________________________________________________________________________________
# concatenate_610 (Concatenate)    (None, None, None, 25 0           conv2d_912[0][0]
#                                                                    conv2d_913[0][0]
#                                                                    conv2d_914[0][0]
# ____________________________________________________________________________________________________
# activation_915 (Activation)      (None, None, None, 25 0           concatenate_610[0][0]
# ____________________________________________________________________________________________________
# conv2d_915 (Conv2D)              (None, None, None, 25 625         activation_915[0][0]
# ____________________________________________________________________________________________________
# activation_916 (Activation)      (None, None, None, 25 0           conv2d_915[0][0]
# ____________________________________________________________________________________________________
# conv2d_916 (Conv2D)              (None, None, None, 1) 225         activation_916[0][0]
# ____________________________________________________________________________________________________
# concatenate_611 (Concatenate)    (None, None, None, 26 0           conv2d_915[0][0]
#                                                                    conv2d_916[0][0]
# ____________________________________________________________________________________________________
# activation_917 (Activation)      (None, None, None, 26 0           concatenate_611[0][0]
# ____________________________________________________________________________________________________
# conv2d_917 (Conv2D)              (None, None, None, 1) 234         activation_917[0][0]
# ____________________________________________________________________________________________________
# concatenate_612 (Concatenate)    (None, None, None, 27 0           conv2d_915[0][0]
#                                                                    conv2d_916[0][0]
#                                                                    conv2d_917[0][0]
# ____________________________________________________________________________________________________
# activation_918 (Activation)      (None, None, None, 27 0           concatenate_612[0][0]
# ____________________________________________________________________________________________________
# conv2d_918 (Conv2D)              (None, None, None, 27 729         activation_918[0][0]
# ____________________________________________________________________________________________________
# activation_919 (Activation)      (None, None, None, 27 0           conv2d_918[0][0]
# ____________________________________________________________________________________________________
# conv2d_919 (Conv2D)              (None, None, None, 1) 243         activation_919[0][0]
# ____________________________________________________________________________________________________
# concatenate_613 (Concatenate)    (None, None, None, 28 0           conv2d_918[0][0]
#                                                                    conv2d_919[0][0]
# ____________________________________________________________________________________________________
# activation_920 (Activation)      (None, None, None, 28 0           concatenate_613[0][0]
# ____________________________________________________________________________________________________
# conv2d_920 (Conv2D)              (None, None, None, 1) 252         activation_920[0][0]
# ____________________________________________________________________________________________________
# concatenate_614 (Concatenate)    (None, None, None, 29 0           conv2d_918[0][0]
#                                                                    conv2d_919[0][0]
#                                                                    conv2d_920[0][0]
# ____________________________________________________________________________________________________
# activation_921 (Activation)      (None, None, None, 29 0           concatenate_614[0][0]
# ____________________________________________________________________________________________________
# conv2d_921 (Conv2D)              (None, None, None, 29 841         activation_921[0][0]
# ____________________________________________________________________________________________________
# activation_922 (Activation)      (None, None, None, 29 0           conv2d_921[0][0]
# ____________________________________________________________________________________________________
# conv2d_922 (Conv2D)              (None, None, None, 1) 261         activation_922[0][0]
# ____________________________________________________________________________________________________
# concatenate_615 (Concatenate)    (None, None, None, 30 0           conv2d_921[0][0]
#                                                                    conv2d_922[0][0]
# ____________________________________________________________________________________________________
# activation_923 (Activation)      (None, None, None, 30 0           concatenate_615[0][0]
# ____________________________________________________________________________________________________
# conv2d_923 (Conv2D)              (None, None, None, 1) 270         activation_923[0][0]
# ____________________________________________________________________________________________________
# concatenate_616 (Concatenate)    (None, None, None, 31 0           conv2d_921[0][0]
#                                                                    conv2d_922[0][0]
#                                                                    conv2d_923[0][0]
# ____________________________________________________________________________________________________
# activation_924 (Activation)      (None, None, None, 31 0           concatenate_616[0][0]
# ____________________________________________________________________________________________________
# conv2d_924 (Conv2D)              (None, None, None, 31 961         activation_924[0][0]
# ____________________________________________________________________________________________________
# activation_925 (Activation)      (None, None, None, 31 0           conv2d_924[0][0]
# ____________________________________________________________________________________________________
# conv2d_925 (Conv2D)              (None, None, None, 1) 279         activation_925[0][0]
# ____________________________________________________________________________________________________
# concatenate_617 (Concatenate)    (None, None, None, 32 0           conv2d_924[0][0]
#                                                                    conv2d_925[0][0]
# ____________________________________________________________________________________________________
# activation_926 (Activation)      (None, None, None, 32 0           concatenate_617[0][0]
# ____________________________________________________________________________________________________
# conv2d_926 (Conv2D)              (None, None, None, 1) 288         activation_926[0][0]
# ____________________________________________________________________________________________________
# concatenate_618 (Concatenate)    (None, None, None, 33 0           conv2d_924[0][0]
#                                                                    conv2d_925[0][0]
#                                                                    conv2d_926[0][0]
# ____________________________________________________________________________________________________
# activation_927 (Activation)      (None, None, None, 33 0           concatenate_618[0][0]
# ____________________________________________________________________________________________________
# conv2d_927 (Conv2D)              (None, None, None, 33 1089        activation_927[0][0]
# ____________________________________________________________________________________________________
# activation_928 (Activation)      (None, None, None, 33 0           conv2d_927[0][0]
# ____________________________________________________________________________________________________
# conv2d_928 (Conv2D)              (None, None, None, 1) 297         activation_928[0][0]
# ____________________________________________________________________________________________________
# concatenate_619 (Concatenate)    (None, None, None, 34 0           conv2d_927[0][0]
#                                                                    conv2d_928[0][0]
# ____________________________________________________________________________________________________
# activation_929 (Activation)      (None, None, None, 34 0           concatenate_619[0][0]
# ____________________________________________________________________________________________________
# conv2d_929 (Conv2D)              (None, None, None, 1) 306         activation_929[0][0]
# ____________________________________________________________________________________________________
# concatenate_620 (Concatenate)    (None, None, None, 35 0           conv2d_927[0][0]
#                                                                    conv2d_928[0][0]
#                                                                    conv2d_929[0][0]
# ____________________________________________________________________________________________________
# activation_930 (Activation)      (None, None, None, 35 0           concatenate_620[0][0]
# ____________________________________________________________________________________________________
# conv2d_930 (Conv2D)              (None, None, None, 35 1225        activation_930[0][0]
# ____________________________________________________________________________________________________
# activation_931 (Activation)      (None, None, None, 35 0           conv2d_930[0][0]
# ____________________________________________________________________________________________________
# conv2d_931 (Conv2D)              (None, None, None, 1) 315         activation_931[0][0]
# ____________________________________________________________________________________________________
# concatenate_621 (Concatenate)    (None, None, None, 36 0           conv2d_930[0][0]
#                                                                    conv2d_931[0][0]
# ____________________________________________________________________________________________________
# activation_932 (Activation)      (None, None, None, 36 0           concatenate_621[0][0]
# ____________________________________________________________________________________________________
# conv2d_932 (Conv2D)              (None, None, None, 1) 324         activation_932[0][0]
# ____________________________________________________________________________________________________
# concatenate_622 (Concatenate)    (None, None, None, 37 0           conv2d_930[0][0]
#                                                                    conv2d_931[0][0]
#                                                                    conv2d_932[0][0]
# ____________________________________________________________________________________________________
# activation_933 (Activation)      (None, None, None, 37 0           concatenate_622[0][0]
# ____________________________________________________________________________________________________
# conv2d_933 (Conv2D)              (None, None, None, 37 1369        activation_933[0][0]
# ____________________________________________________________________________________________________
# activation_934 (Activation)      (None, None, None, 37 0           conv2d_933[0][0]
# ____________________________________________________________________________________________________
# conv2d_934 (Conv2D)              (None, None, None, 1) 333         activation_934[0][0]
# ____________________________________________________________________________________________________
# concatenate_623 (Concatenate)    (None, None, None, 38 0           conv2d_933[0][0]
#                                                                    conv2d_934[0][0]
# ____________________________________________________________________________________________________
# activation_935 (Activation)      (None, None, None, 38 0           concatenate_623[0][0]
# ____________________________________________________________________________________________________
# conv2d_935 (Conv2D)              (None, None, None, 1) 342         activation_935[0][0]
# ____________________________________________________________________________________________________
# concatenate_624 (Concatenate)    (None, None, None, 39 0           conv2d_933[0][0]
#                                                                    conv2d_934[0][0]
#                                                                    conv2d_935[0][0]
# ____________________________________________________________________________________________________
# activation_936 (Activation)      (None, None, None, 39 0           concatenate_624[0][0]
# ____________________________________________________________________________________________________
# conv2d_936 (Conv2D)              (None, None, None, 39 1521        activation_936[0][0]
# ____________________________________________________________________________________________________
# activation_937 (Activation)      (None, None, None, 39 0           conv2d_936[0][0]
# ____________________________________________________________________________________________________
# conv2d_937 (Conv2D)              (None, None, None, 1) 351         activation_937[0][0]
# ____________________________________________________________________________________________________
# concatenate_625 (Concatenate)    (None, None, None, 40 0           conv2d_936[0][0]
#                                                                    conv2d_937[0][0]
# ____________________________________________________________________________________________________
# activation_938 (Activation)      (None, None, None, 40 0           concatenate_625[0][0]
# ____________________________________________________________________________________________________
# conv2d_938 (Conv2D)              (None, None, None, 1) 360         activation_938[0][0]
# ____________________________________________________________________________________________________
# concatenate_626 (Concatenate)    (None, None, None, 41 0           conv2d_936[0][0]
#                                                                    conv2d_937[0][0]
#                                                                    conv2d_938[0][0]
# ____________________________________________________________________________________________________
# activation_939 (Activation)      (None, None, None, 41 0           concatenate_626[0][0]
# ____________________________________________________________________________________________________
# conv2d_939 (Conv2D)              (None, None, None, 41 1681        activation_939[0][0]
# ____________________________________________________________________________________________________
# activation_940 (Activation)      (None, None, None, 41 0           conv2d_939[0][0]
# ____________________________________________________________________________________________________
# conv2d_940 (Conv2D)              (None, None, None, 1) 369         activation_940[0][0]
# ____________________________________________________________________________________________________
# concatenate_627 (Concatenate)    (None, None, None, 42 0           conv2d_939[0][0]
#                                                                    conv2d_940[0][0]
# ____________________________________________________________________________________________________
# activation_941 (Activation)      (None, None, None, 42 0           concatenate_627[0][0]
# ____________________________________________________________________________________________________
# conv2d_941 (Conv2D)              (None, None, None, 1) 378         activation_941[0][0]
# ____________________________________________________________________________________________________
# concatenate_628 (Concatenate)    (None, None, None, 43 0           conv2d_939[0][0]
#                                                                    conv2d_940[0][0]
#                                                                    conv2d_941[0][0]
# ____________________________________________________________________________________________________
# activation_942 (Activation)      (None, None, None, 43 0           concatenate_628[0][0]
# ____________________________________________________________________________________________________
# conv2d_942 (Conv2D)              (None, None, None, 43 1849        activation_942[0][0]
# ____________________________________________________________________________________________________
# activation_943 (Activation)      (None, None, None, 43 0           conv2d_942[0][0]
# ____________________________________________________________________________________________________
# conv2d_943 (Conv2D)              (None, None, None, 1) 387         activation_943[0][0]
# ____________________________________________________________________________________________________
# concatenate_629 (Concatenate)    (None, None, None, 44 0           conv2d_942[0][0]
#                                                                    conv2d_943[0][0]
# ____________________________________________________________________________________________________
# activation_944 (Activation)      (None, None, None, 44 0           concatenate_629[0][0]
# ____________________________________________________________________________________________________
# conv2d_944 (Conv2D)              (None, None, None, 1) 396         activation_944[0][0]
# ____________________________________________________________________________________________________
# concatenate_630 (Concatenate)    (None, None, None, 45 0           conv2d_942[0][0]
#                                                                    conv2d_943[0][0]
#                                                                    conv2d_944[0][0]
# ____________________________________________________________________________________________________
# activation_945 (Activation)      (None, None, None, 45 0           concatenate_630[0][0]
# ____________________________________________________________________________________________________
# conv2d_945 (Conv2D)              (None, None, None, 45 2025        activation_945[0][0]
# ____________________________________________________________________________________________________
# activation_946 (Activation)      (None, None, None, 45 0           conv2d_945[0][0]
# ____________________________________________________________________________________________________
# conv2d_946 (Conv2D)              (None, None, None, 1) 405         activation_946[0][0]
# ____________________________________________________________________________________________________
# concatenate_631 (Concatenate)    (None, None, None, 46 0           conv2d_945[0][0]
#                                                                    conv2d_946[0][0]
# ____________________________________________________________________________________________________
# activation_947 (Activation)      (None, None, None, 46 0           concatenate_631[0][0]
# ____________________________________________________________________________________________________
# conv2d_947 (Conv2D)              (None, None, None, 1) 414         activation_947[0][0]
# ____________________________________________________________________________________________________
# concatenate_632 (Concatenate)    (None, None, None, 47 0           conv2d_945[0][0]
#                                                                    conv2d_946[0][0]
#                                                                    conv2d_947[0][0]
# ____________________________________________________________________________________________________
# activation_948 (Activation)      (None, None, None, 47 0           concatenate_632[0][0]
# ____________________________________________________________________________________________________
# conv2d_948 (Conv2D)              (None, None, None, 47 2209        activation_948[0][0]
# ____________________________________________________________________________________________________
# activation_949 (Activation)      (None, None, None, 47 0           conv2d_948[0][0]
# ____________________________________________________________________________________________________
# conv2d_949 (Conv2D)              (None, None, None, 1) 423         activation_949[0][0]
# ____________________________________________________________________________________________________
# concatenate_633 (Concatenate)    (None, None, None, 48 0           conv2d_948[0][0]
#                                                                    conv2d_949[0][0]
# ____________________________________________________________________________________________________
# activation_950 (Activation)      (None, None, None, 48 0           concatenate_633[0][0]
# ____________________________________________________________________________________________________
# conv2d_950 (Conv2D)              (None, None, None, 1) 432         activation_950[0][0]
# ____________________________________________________________________________________________________
# concatenate_634 (Concatenate)    (None, None, None, 49 0           conv2d_948[0][0]
#                                                                    conv2d_949[0][0]
#                                                                    conv2d_950[0][0]
# ____________________________________________________________________________________________________
# activation_951 (Activation)      (None, None, None, 49 0           concatenate_634[0][0]
# ____________________________________________________________________________________________________
# conv2d_951 (Conv2D)              (None, None, None, 49 2401        activation_951[0][0]
# ____________________________________________________________________________________________________
# activation_952 (Activation)      (None, None, None, 49 0           conv2d_951[0][0]
# ____________________________________________________________________________________________________
# conv2d_952 (Conv2D)              (None, None, None, 1) 441         activation_952[0][0]
# ____________________________________________________________________________________________________
# concatenate_635 (Concatenate)    (None, None, None, 50 0           conv2d_951[0][0]
#                                                                    conv2d_952[0][0]
# ____________________________________________________________________________________________________
# activation_953 (Activation)      (None, None, None, 50 0           concatenate_635[0][0]
# ____________________________________________________________________________________________________
# conv2d_953 (Conv2D)              (None, None, None, 1) 450         activation_953[0][0]
# ____________________________________________________________________________________________________
# concatenate_636 (Concatenate)    (None, None, None, 51 0           conv2d_951[0][0]
#                                                                    conv2d_952[0][0]
#                                                                    conv2d_953[0][0]
# ____________________________________________________________________________________________________
# activation_954 (Activation)      (None, None, None, 51 0           concatenate_636[0][0]
# ____________________________________________________________________________________________________
# conv2d_954 (Conv2D)              (None, None, None, 51 2601        activation_954[0][0]
# ____________________________________________________________________________________________________
# activation_955 (Activation)      (None, None, None, 51 0           conv2d_954[0][0]
# ____________________________________________________________________________________________________
# conv2d_955 (Conv2D)              (None, None, None, 1) 459         activation_955[0][0]
# ____________________________________________________________________________________________________
# concatenate_637 (Concatenate)    (None, None, None, 52 0           conv2d_954[0][0]
#                                                                    conv2d_955[0][0]
# ____________________________________________________________________________________________________
# activation_956 (Activation)      (None, None, None, 52 0           concatenate_637[0][0]
# ____________________________________________________________________________________________________
# conv2d_956 (Conv2D)              (None, None, None, 1) 468         activation_956[0][0]
# ____________________________________________________________________________________________________
# concatenate_638 (Concatenate)    (None, None, None, 53 0           conv2d_954[0][0]
# ...
# conv2d_1005 (Conv2D)             (None, None, None, 85 7225        activation_1005[0][0]
# ____________________________________________________________________________________________________
# activation_1006 (Activation)     (None, None, None, 85 0           conv2d_1005[0][0]
# ____________________________________________________________________________________________________
# conv2d_1006 (Conv2D)             (None, None, None, 1) 765         activation_1006[0][0]
# ____________________________________________________________________________________________________
# concatenate_671 (Concatenate)    (None, None, None, 86 0           conv2d_1005[0][0]
#                                                                    conv2d_1006[0][0]
# ____________________________________________________________________________________________________
# activation_1007 (Activation)     (None, None, None, 86 0           concatenate_671[0][0]
# ____________________________________________________________________________________________________
# conv2d_1007 (Conv2D)             (None, None, None, 1) 774         activation_1007[0][0]
# ____________________________________________________________________________________________________
# concatenate_672 (Concatenate)    (None, None, None, 87 0           conv2d_1005[0][0]
#                                                                    conv2d_1006[0][0]
#                                                                    conv2d_1007[0][0]
# ____________________________________________________________________________________________________
# activation_1008 (Activation)     (None, None, None, 87 0           concatenate_672[0][0]
# ____________________________________________________________________________________________________
# conv2d_1008 (Conv2D)             (None, None, None, 87 7569        activation_1008[0][0]
# ____________________________________________________________________________________________________
# activation_1009 (Activation)     (None, None, None, 87 0           conv2d_1008[0][0]
# ____________________________________________________________________________________________________
# conv2d_1009 (Conv2D)             (None, None, None, 1) 783         activation_1009[0][0]
# ____________________________________________________________________________________________________
# concatenate_673 (Concatenate)    (None, None, None, 88 0           conv2d_1008[0][0]
#                                                                    conv2d_1009[0][0]
# ____________________________________________________________________________________________________
# activation_1010 (Activation)     (None, None, None, 88 0           concatenate_673[0][0]
# ____________________________________________________________________________________________________
# conv2d_1010 (Conv2D)             (None, None, None, 1) 792         activation_1010[0][0]
# ____________________________________________________________________________________________________
# concatenate_674 (Concatenate)    (None, None, None, 89 0           conv2d_1008[0][0]
#                                                                    conv2d_1009[0][0]
#                                                                    conv2d_1010[0][0]
# ____________________________________________________________________________________________________
# activation_1011 (Activation)     (None, None, None, 89 0           concatenate_674[0][0]
# ____________________________________________________________________________________________________
# conv2d_1011 (Conv2D)             (None, None, None, 89 7921        activation_1011[0][0]
# ____________________________________________________________________________________________________
# activation_1012 (Activation)     (None, None, None, 89 0           conv2d_1011[0][0]
# ____________________________________________________________________________________________________
# conv2d_1012 (Conv2D)             (None, None, None, 1) 801         activation_1012[0][0]
# ____________________________________________________________________________________________________
# concatenate_675 (Concatenate)    (None, None, None, 90 0           conv2d_1011[0][0]
#                                                                    conv2d_1012[0][0]
# ____________________________________________________________________________________________________
# activation_1013 (Activation)     (None, None, None, 90 0           concatenate_675[0][0]
# ____________________________________________________________________________________________________
# conv2d_1013 (Conv2D)             (None, None, None, 1) 810         activation_1013[0][0]
# ____________________________________________________________________________________________________
# concatenate_676 (Concatenate)    (None, None, None, 91 0           conv2d_1011[0][0]
#                                                                    conv2d_1012[0][0]
#                                                                    conv2d_1013[0][0]
# ____________________________________________________________________________________________________
# activation_1014 (Activation)     (None, None, None, 91 0           concatenate_676[0][0]
# ____________________________________________________________________________________________________
# conv2d_1014 (Conv2D)             (None, None, None, 91 8281        activation_1014[0][0]
# ____________________________________________________________________________________________________
# activation_1015 (Activation)     (None, None, None, 91 0           conv2d_1014[0][0]
# ____________________________________________________________________________________________________
# conv2d_1015 (Conv2D)             (None, None, None, 1) 819         activation_1015[0][0]
# ____________________________________________________________________________________________________
# concatenate_677 (Concatenate)    (None, None, None, 92 0           conv2d_1014[0][0]
#                                                                    conv2d_1015[0][0]
# ____________________________________________________________________________________________________
# activation_1016 (Activation)     (None, None, None, 92 0           concatenate_677[0][0]
# ____________________________________________________________________________________________________
# conv2d_1016 (Conv2D)             (None, None, None, 1) 828         activation_1016[0][0]
# ____________________________________________________________________________________________________
# concatenate_678 (Concatenate)    (None, None, None, 93 0           conv2d_1014[0][0]
#                                                                    conv2d_1015[0][0]
#                                                                    conv2d_1016[0][0]
# ____________________________________________________________________________________________________
# activation_1017 (Activation)     (None, None, None, 93 0           concatenate_678[0][0]
# ____________________________________________________________________________________________________
# conv2d_1017 (Conv2D)             (None, None, None, 93 8649        activation_1017[0][0]
# ____________________________________________________________________________________________________
# activation_1018 (Activation)     (None, None, None, 93 0           conv2d_1017[0][0]
# ____________________________________________________________________________________________________
# conv2d_1018 (Conv2D)             (None, None, None, 1) 837         activation_1018[0][0]
# ____________________________________________________________________________________________________
# concatenate_679 (Concatenate)    (None, None, None, 94 0           conv2d_1017[0][0]
#                                                                    conv2d_1018[0][0]
# ____________________________________________________________________________________________________
# activation_1019 (Activation)     (None, None, None, 94 0           concatenate_679[0][0]
# ____________________________________________________________________________________________________
# conv2d_1019 (Conv2D)             (None, None, None, 1) 846         activation_1019[0][0]
# ____________________________________________________________________________________________________
# concatenate_680 (Concatenate)    (None, None, None, 95 0           conv2d_1017[0][0]
#                                                                    conv2d_1018[0][0]
#                                                                    conv2d_1019[0][0]
# ____________________________________________________________________________________________________
# activation_1020 (Activation)     (None, None, None, 95 0           concatenate_680[0][0]
# ____________________________________________________________________________________________________
# conv2d_1020 (Conv2D)             (None, None, None, 95 9025        activation_1020[0][0]
# ____________________________________________________________________________________________________
# activation_1021 (Activation)     (None, None, None, 95 0           conv2d_1020[0][0]
# ____________________________________________________________________________________________________
# conv2d_1021 (Conv2D)             (None, None, None, 1) 855         activation_1021[0][0]
# ____________________________________________________________________________________________________
# concatenate_681 (Concatenate)    (None, None, None, 96 0           conv2d_1020[0][0]
#                                                                    conv2d_1021[0][0]
# ____________________________________________________________________________________________________
# activation_1022 (Activation)     (None, None, None, 96 0           concatenate_681[0][0]
# ____________________________________________________________________________________________________
# conv2d_1022 (Conv2D)             (None, None, None, 1) 864         activation_1022[0][0]
# ____________________________________________________________________________________________________
# concatenate_682 (Concatenate)    (None, None, None, 97 0           conv2d_1020[0][0]
#                                                                    conv2d_1021[0][0]
#                                                                    conv2d_1022[0][0]
# ____________________________________________________________________________________________________
# activation_1023 (Activation)     (None, None, None, 97 0           concatenate_682[0][0]
# ____________________________________________________________________________________________________
# conv2d_1023 (Conv2D)             (None, None, None, 97 9409        activation_1023[0][0]
# ____________________________________________________________________________________________________
# activation_1024 (Activation)     (None, None, None, 97 0           conv2d_1023[0][0]
# ____________________________________________________________________________________________________
# conv2d_1024 (Conv2D)             (None, None, None, 1) 873         activation_1024[0][0]
# ____________________________________________________________________________________________________
# concatenate_683 (Concatenate)    (None, None, None, 98 0           conv2d_1023[0][0]
#                                                                    conv2d_1024[0][0]
# ____________________________________________________________________________________________________
# activation_1025 (Activation)     (None, None, None, 98 0           concatenate_683[0][0]
# ____________________________________________________________________________________________________
# conv2d_1025 (Conv2D)             (None, None, None, 1) 882         activation_1025[0][0]
# ____________________________________________________________________________________________________
# concatenate_684 (Concatenate)    (None, None, None, 99 0           conv2d_1023[0][0]
#                                                                    conv2d_1024[0][0]
#                                                                    conv2d_1025[0][0]
# ____________________________________________________________________________________________________
# activation_1026 (Activation)     (None, None, None, 99 0           concatenate_684[0][0]
# ____________________________________________________________________________________________________
# conv2d_1026 (Conv2D)             (None, None, None, 99 9801        activation_1026[0][0]
# ____________________________________________________________________________________________________
# activation_1027 (Activation)     (None, None, None, 99 0           conv2d_1026[0][0]
# ____________________________________________________________________________________________________
# conv2d_1027 (Conv2D)             (None, None, None, 1) 891         activation_1027[0][0]
# ____________________________________________________________________________________________________
# concatenate_685 (Concatenate)    (None, None, None, 10 0           conv2d_1026[0][0]
#                                                                    conv2d_1027[0][0]
# ____________________________________________________________________________________________________
# activation_1028 (Activation)     (None, None, None, 10 0           concatenate_685[0][0]
# ____________________________________________________________________________________________________
# conv2d_1028 (Conv2D)             (None, None, None, 1) 900         activation_1028[0][0]
# ____________________________________________________________________________________________________
# concatenate_686 (Concatenate)    (None, None, None, 10 0           conv2d_1026[0][0]
#                                                                    conv2d_1027[0][0]
#                                                                    conv2d_1028[0][0]
# ____________________________________________________________________________________________________
# activation_1029 (Activation)     (None, None, None, 10 0           concatenate_686[0][0]
# ____________________________________________________________________________________________________
# conv2d_1029 (Conv2D)             (None, None, None, 10 10201       activation_1029[0][0]
# ____________________________________________________________________________________________________
# final_conv2D (Conv2D)            (None, None, None, 3) 2727        conv2d_1029[0][0]
# ====================================================================================================
# Total params: 225,099
# Trainable params: 225,099
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
keyname = "_DENSE_NET"
now=datetime.datetime.now()
save_file=os.path.join(save_results,now.strftime("%Y-%m-%d %H-%M")+keyname)
os.mkdir(save_file)
save_pred = os.path.join(save_file,'Epoch_Predictions')
os.mkdir(save_pred)
save_model = os.path.join(save_file,'Epoch_Models')
os.mkdir(save_model)

with open(os.path.join(save_file,'Model_Summary.txt'),'w') as fh:
    model.summary(print_fn=lambda x: fh.write(x + '\n'))
    
#rmsprop = RMSprop(lr=0.0005, rho=0.9, epsilon=1e-08, decay=0.0)
optimizer_func = Nadam(lr=0.00002, beta_1=0.9, beta_2=0.999, epsilon=1e-08, schedule_decay=0.004)
loss_func='mse'

early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
tbCallBack = keras.callbacks.TensorBoard(log_dir=os.path.join(save_file,'TNSR_BRD'), histogram_freq=0, write_graph=True, write_images=True)
csv_logger = keras.callbacks.CSVLogger(os.path.join(save_file,'training.log'), separator=',', append=False)
epoch_predict = train_UNET.Save_predictions(save_pred)
model_checkpoint = keras.callbacks.ModelCheckpoint(os.path.join(save_model,'model.{epoch:02d}-{loss:.2f}.hdf5'), monitor='loss')

model.compile(optimizer=optimizer_func,loss=loss_func)

# %%
fls = len(os.listdir(load_training))

                            #train_dir, patch_size, batch_size
train_generator = train_UNET.train_generator_rgb(load_training,64,32)

history = model.fit_generator(generator = train_generator,steps_per_epoch=3*fls,
                             epochs = 200,callbacks = [tbCallBack,csv_logger,epoch_predict,model_checkpoint])
print(history.history)

model.save(os.path.join(save_file,'DeMos_mod.h5'))
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Incompatible shapes: [32,64,64,3] vs. [32,128,128,3]
# 	 [[Node: loss_1/final_conv2D_loss/sub = Sub[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"](final_conv2D_4/convolution, _arg_final_conv2D_target_1_0_1/_1491)]]
# 	 [[Node: loss_1/add_148/_1527 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_23999_loss_1/add_148", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-25-3ecc3e5c5fbe> in <module>()
#       5
#       6 history = model.fit_generator(generator = train_generator,steps_per_epoch=3*fls,
# ----> 7                              epochs = 200,callbacks = [tbCallBack,csv_logger,epoch_predict,model_checkpoint])
#       8 print(history.history)
#       9
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2040                     outs = self.train_on_batch(x, y,
#    2041                                                sample_weight=sample_weight,
# -> 2042                                                class_weight=class_weight)
#    2043
#    2044                     if not isinstance(outs, list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1760             ins = x + y + sample_weights
#    1761         self._make_train_function()
# -> 1762         outputs = self.train_function(ins)
#    1763         if len(outputs) == 1:
#    1764             return outputs[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: Incompatible shapes: [32,64,64,3] vs. [32,128,128,3]
# 	 [[Node: loss_1/final_conv2D_loss/sub = Sub[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"](final_conv2D_4/convolution, _arg_final_conv2D_target_1_0_1/_1491)]]
# 	 [[Node: loss_1/add_148/_1527 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_23999_loss_1/add_148", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# Caused by op 'loss_1/final_conv2D_loss/sub', defined at:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2808, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-24-f59ab8c778c9>", line 23, in <module>
#     model.compile(optimizer=optimizer_func,loss=loss_func)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py", line 850, in compile
#     sample_weight, mask)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py", line 450, in weighted
#     score_array = fn(y_true, y_pred)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\keras\losses.py", line 8, in mean_squared_error
#     return K.mean(K.square(y_pred - y_true), axis=-1)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py", line 865, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 2629, in _sub
#     result = _op_def_lib.apply_op("Sub", x=x, y=y, name=name)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2630, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1204, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Incompatible shapes: [32,64,64,3] vs. [32,128,128,3]
# 	 [[Node: loss_1/final_conv2D_loss/sub = Sub[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"](final_conv2D_4/convolution, _arg_final_conv2D_target_1_0_1/_1491)]]
# 	 [[Node: loss_1/add_148/_1527 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_23999_loss_1/add_148", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]

# %%
#Test Kodak
data ={}

kodak_dir = r'C:\Users\buggyr\Mosaic_Experiments\data\interim\Kodak'
ls = len(os.listdir(kodak_dir))

kodak_generator = train_UNET.predict_generator_rgb(kodak_dir)

# k_pred = model.predict_generator(kodak_generator, steps = ls)

res_Kodak = train_UNET.predict_generator(model,kodak_generator,ls,data,5)

data['Kodak_IMGS_PSNR'] = res_Kodak[0]
data['Kodak_IMGS_SSIM'] = res_Kodak[1]
data['Kodak_AVG_PSNR']  = res_Kodak[2]
data['Kodak_AVG_SSIM']  = res_Kodak[3]

# %%
#Test McManus
McM_dir = r'C:\Users\buggyr\Mosaic_Experiments\data\interim\McM'
ls = len(os.listdir(McM_dir))

McM_generator = train_UNET.predict_generator_rgb(McM_dir)

# k_pred = model.predict_generator(kodak_generator, steps = ls)

res_McM = train_UNET.predict_generator(model,McM_generator,ls,data,5)

data['McM_IMGS_PSNR'] = res_McM[0]
data['McM_IMGS_SSIM'] = res_McM[1]
data['McM_AVG_PSNR']  = res_McM[2]
data['McM_AVG_SSIM']  = res_McM[3]

# %%
#Write Results
data['Parameters'] = {
    'Loss Function': loss_func,
    'Optimizer':str(type(optimizer_func))
}
data['Training Set'] = {
    'Training Path': load_training,
}

with open(os.path.join(save_file,'results.txt'), 'w') as outfile:  
    json.dump(data, outfile,indent=4)
